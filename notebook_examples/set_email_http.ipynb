# %% [markdown]
# <a href="https://colab.research.google.com/github/microprediction/microprediction/blob/master/set_email_http.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests

# %% [markdown]
# ### Add your email
# (best to do so directly for now. The next release of the microprediction client will add a set_email method)

# %%
import requests 
res = requests.put('https://api.microprediction.org/email/4c7b09f29b8b7eb580b48ada674142cd', params={'email': 'me@gmail.com'})
res.json()
# Out:
# 0
