# %% [markdown]
# <a href="https://colab.research.google.com/github/microprediction/microprediction/blob/master/Python_Module_3_Getting_History.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install microprediction

# %%
from microprediction import MicroReader
reader = MicroReader()
lagged_values = reader.get_lagged_values(name='die.json')
import matplotlib.pyplot as plt
plt.plot(lagged_values)

# %%
lagged_times = reader.get_lagged_times(name='die.json')
print(lagged_times[:5])
lagged_times[0]
import time 
time.time()-lagged_times[0]
# Out:
# [1602608228.5353885, 1602607568.4505043, 1602606908.3574033, 1602606248.2526648, 1602605588.1498737]
# 530.9450130462646
